# %% [markdown]
# # Rotating Coild Data Analysis for BO QF Magnets

# %% [markdown]
# ## Import libraries and Load measurement data

# %%
import numpy as np
import matplotlib
matplotlib.use('Qt5Agg')

# %matplotlib notebook

import matplotlib.pyplot as plt
from rotcoil import *

# %%
# Define serial numbers, one for each magnet

serials = [
#     '002', # different folder structure!
    '006', '007', '009', 
#     '010', # magnetic center off
    '011', '012', '013', '014', '015', '016', '017', '018', '019', '020',
#     '021', # skew multipole, max excitation error
    '022', '023', '024', '025', '026', '027', '028', '029', '030',
    '031', '032',
#     '033',  # different excitations at low currents
    '034', '035', '036', '037', '038', '039', '040',
    '041', '042', '043', '044', '045', '046', '047', '048', '049', '050',
    '051', '052', '053', '054', '055', '056', '057', '058', 
]

# Load all data
data = MagnetsAnalysis(RotCoilMeas_BOQuadQF, serials)
data.init()

# Print info
data.print_info()
# Out:
# index: 00, serial_number: 006, data sets: ['M2', 'M1', 'M3']
# index: 01, serial_number: 007, data sets: ['M2', 'M1', 'M3']
# index: 02, serial_number: 009, data sets: ['M2', 'M1', 'M3']
# index: 03, serial_number: 011, data sets: ['M2', 'M1', 'M3']
# index: 04, serial_number: 012, data sets: ['M2', 'M1', 'M3']
# index: 05, serial_number: 013, data sets: ['M2', 'M1', 'M3']
# index: 06, serial_number: 014, data sets: ['M2', 'M1', 'M3']
# index: 07, serial_number: 015, data sets: ['M2', 'M1', 'M3']
# index: 08, serial_number: 016, data sets: ['M2', 'M1', 'M3']
# index: 09, serial_number: 017, data sets: ['M2', 'M1', 'M3']
# index: 10, serial_number: 018, data sets: ['M2', 'M1', 'M3']
# index: 11, serial_number: 019, data sets: ['M2', 'M1', 'M3']
# index: 12, serial_number: 020, data sets: ['M2', 'M1', 'M3']
# index: 13, serial_number: 022, data sets: ['M2', 'M1', 'M3']
# index: 14, serial_number: 023, data sets: ['M2', 'M1', 'M3']
# index: 15, serial_number: 024, data sets: ['M2', 'M1', 'M3']
# index: 16, serial_number: 025, data sets: ['M2', 'M1', 'M3']
# index: 17, serial_number: 026, data sets: ['M2', 'M1', 'M3']
# index: 18, serial_number: 027, data sets: ['M2', 'M1', 'M3']
# index: 19, serial_number: 028, data sets: ['M2', 'M1', 'M3']
# index: 20, serial_number: 029, data sets: ['M2', 'M1', 'M3']
# index: 21, serial_number: 030, data sets: ['M2', 'M1', 'M3']
# index: 22, serial_number: 031, data sets: ['M2', 'M1', 'M3']
# index: 23, serial_number: 032, data sets: ['M2', 'M1', 'M3']
# index: 24, serial_number: 034, data sets: ['M2', 'M1', 'M3']
# index: 25, serial_number: 035, data sets: ['M2', 'M1', 'M3']
# index: 26, serial_number: 036, data sets: ['M2', 'M1', 'M3']
# index: 27, serial_number: 037, data sets: ['M2', 'M1', 'M3']
# index: 28, serial_number: 038, data sets: ['M2', 'M1', 'M3']
# index: 29, serial_number: 039, data sets: ['M2', 'M1', 'M3']
# index: 30, serial_number: 040, data sets: ['M2', 'M1', 'M3']
# index: 31, serial_number: 041, data sets: ['M2', 'M1', 'M3']
# index: 32, serial_number: 042, data sets: ['M2', 'M1', 'M3']
# index: 33, serial_number: 043, data sets: ['M2', 'M1', 'M3']
# index: 34, serial_number: 044, data sets: ['M2', 'M1', 'M3']
# index: 35, serial_number: 045, data sets: ['M2', 'M1', 'M3']
# index: 36, serial_number: 046, data sets: ['M2', 'M1', 'M3']
# index: 37, serial_number: 047, data sets: ['M2', 'M1', 'M3']
# index: 38, serial_number: 048, data sets: ['M2', 'M1', 'M3']
# index: 39, serial_number: 049, data sets: ['M2', 'M1', 'M3']
# index: 40, serial_number: 050, data sets: ['M2', 'M1', 'M3']
# index: 41, serial_number: 051, data sets: ['M2', 'M1', 'M3']
# index: 42, serial_number: 052, data sets: ['M2', 'M1', 'M3']
# index: 43, serial_number: 053, data sets: ['M1', 'M2', 'M3']
# index: 44, serial_number: 054, data sets: ['M2', 'M1', 'M3']
# index: 45, serial_number: 055, data sets: ['M2', 'M1', 'M3']
# index: 46, serial_number: 056, data sets: ['M2', 'M1', 'M3']
# index: 47, serial_number: 057, data sets: ['M2', 'M1', 'M3']
# index: 48, serial_number: 058, data sets: ['M2', 'M1', 'M3']

# %% [markdown]
# ## Maximum Integrated Quadrupole

# %%
# gets integrated strength at maximum current for all magnets
data.main_intmpole_at_max_current('M1')
# Out:
# index:00, serial:006, idx:11, max_current:  +129.9988 [A], diff_spec: +13.39 [%]
# index:01, serial:007, idx:11, max_current:  +129.9946 [A], diff_spec: +13.34 [%]
# index:02, serial:009, idx:11, max_current:  +130.0267 [A], diff_spec: +13.49 [%]
# index:03, serial:011, idx:11, max_current:  +130.0058 [A], diff_spec: +13.32 [%]
# index:04, serial:012, idx:11, max_current:  +130.0098 [A], diff_spec: +13.41 [%]
# index:05, serial:013, idx:11, max_current:  +130.0115 [A], diff_spec: +13.32 [%]
# index:06, serial:014, idx:11, max_current:  +130.0082 [A], diff_spec: +13.19 [%]
# index:07, serial:015, idx:11, max_current:  +130.0260 [A], diff_spec: +13.21 [%]
# index:08, serial:016, idx:11, max_current:  +130.0284 [A], diff_spec: +13.35 [%]
# index:09, serial:017, idx:11, max_current:  +130.0015 [A], diff_spec: +13.28 [%]
# index:10, serial:018, idx:11, max_current:  +130.0252 [A], diff_spec: +13.37 [%]
# index:11, serial:019, idx:11, max_current:  +130.0137 [A], diff_spec: +13.35 [%]
# index:12, serial:020, idx:11, max_current:  +130.0071 [A], diff_spec: +13.40 [%]
# index:13, serial:022, idx:11, max_current:  +130.0251 [A], diff_spec: +13.53 [%]
# index:14, serial:023, idx:11, max_current:  +129.9963 [A], diff_spec: +13.55 [%]
# index:15, serial:024, idx:11, max_current:  +130.0106 [A], diff_spec: +13.47 [%]
# index:16, serial:025, idx:11, max_current:  +129.9984 [A], diff_spec: +13.47 [%]
# index:17, serial:026, idx:11, max_current:  +130.0051 [A], diff_spec: +13.56 [%]
# index:18, serial:027, idx:11, max_current:  +130.0109 [A], diff_spec: +13.32 [%]
# index:19, serial:028, idx:11, max_current:  +130.0102 [A], diff_spec: +13.35 [%]
# index:20, serial:029, idx:11, max_current:  +130.0204 [A], diff_spec: +13.40 [%]
# index:21, serial:030, idx:11, max_current:  +130.0262 [A], diff_spec: +13.44 [%]
# index:22, serial:031, idx:11, max_current:  +130.0097 [A], diff_spec: +13.43 [%]
# index:23, serial:032, idx:11, max_current:  +130.0125 [A], diff_spec: +13.45 [%]
# index:24, serial:034, idx:11, max_current:  +130.0146 [A], diff_spec: +13.41 [%]
# index:25, serial:035, idx:11, max_current:  +130.0079 [A], diff_spec: +13.43 [%]
# index:26, serial:036, idx:11, max_current:  +130.0461 [A], diff_spec: +13.52 [%]
# index:27, serial:037, idx:11, max_current:  +130.0139 [A], diff_spec: +13.37 [%]
# index:28, serial:038, idx:11, max_current:  +130.0033 [A], diff_spec: +13.34 [%]
# index:29, serial:039, idx:11, max_current:  +130.0164 [A], diff_spec: +13.26 [%]
# index:30, serial:040, idx:11, max_current:  +130.0418 [A], diff_spec: +13.32 [%]
# index:31, serial:041, idx:11, max_current:  +130.0135 [A], diff_spec: +13.32 [%]
# index:32, serial:042, idx:11, max_current:  +129.9381 [A], diff_spec: +13.50 [%]
# index:33, serial:043, idx:11, max_current:  +130.0026 [A], diff_spec: +13.50 [%]
# index:34, serial:044, idx:11, max_current:  +129.9974 [A], diff_spec: +13.56 [%]
# index:35, serial:045, idx:11, max_current:  +130.0021 [A], diff_spec: +13.59 [%]
# index:36, serial:046, idx:11, max_current:  +130.0022 [A], diff_spec: +13.41 [%]
# index:37, serial:047, idx:11, max_current:  +130.0160 [A], diff_spec: +13.23 [%]
# index:38, serial:048, idx:11, max_current:  +130.0096 [A], diff_spec: +13.50 [%]
# index:39, serial:049, idx:11, max_current:  +130.0054 [A], diff_spec: +13.37 [%]
# index:40, serial:050, idx:11, max_current:  +130.0022 [A], diff_spec: +13.36 [%]
# index:41, serial:051, idx:11, max_current:  +130.0347 [A], diff_spec: +13.40 [%]
# index:42, serial:052, idx:11, max_current:  +130.0218 [A], diff_spec: +13.32 [%]
# index:43, serial:053, idx:11, max_current:  +130.0079 [A], diff_spec: +13.31 [%]
# index:44, serial:054, idx:11, max_current:  +130.0200 [A], diff_spec: +13.39 [%]
# index:45, serial:055, idx:11, max_current:  +130.0093 [A], diff_spec: +13.39 [%]
# index:46, serial:056, idx:11, max_current:  +130.0267 [A], diff_spec: +13.39 [%]
# index:47, serial:057, idx:11, max_current:  +130.0106 [A], diff_spec: +13.54 [%]
# index:48, serial:058, idx:11, max_current:  +130.0090 [A], diff_spec: +13.54 [%]

# %%
# plot data comparison with spec
data.main_intmpole_at_max_current_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Magnetic Center

# %%
# Horizontal center for all magnets x currents
data.magnetic_center_direction_plot('M1', 'X', plt)
plt.show()

# each magnet is represented by two curves: one rampup and one rampdown
# Out:
# <img src="data:image/png;base64,..." width="640">
# Horizontal center at maximum current [um]: -10.92 ± 14.20

# %%
# Vertical center for all magnets y currents
data.magnetic_center_direction_plot('M1', 'Y', plt)
plt.show()

# each magnet is represented by two curves: one rampup and one rampdown
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vertical center at maximum current [um]: +26.61 ± 10.11

# %%
# Horizontal and vertical positions of all magnets
data.magnetic_center_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Transverse plane positions
data.magnetic_center_transverse_plot('M1', plt)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Ramp Up

# %%
# Plot rampup integrated strength of main multipole and compare it to nominal values and maximum spec

data.rampup_excitation_curve_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Nominal Integrated Quadrupole [T]:
# BO-Fam:MA-QF    : -3.773610

# %%
# Plot rampup dispersion amongst magnets

data.rampup_excitation_curve_dispersion_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Print random integrated main strength for various currents

data.rampup_excitation_curve_rms_error_print('M1')
# Out:
# current:   +0.013 [A], rms_error:  6.3097 [%], max_error: 14.2763 [%]
# current:   +2.011 [A], rms_error:  0.6506 [%], max_error:  1.4319 [%]
# current:   +4.010 [A], rms_error:  0.3231 [%], max_error:  0.7012 [%]
# current:   +6.007 [A], rms_error:  0.2266 [%], max_error:  0.6120 [%]
# current:   +8.006 [A], rms_error:  0.1542 [%], max_error:  0.3415 [%]
# current:  +10.004 [A], rms_error:  0.1227 [%], max_error:  0.2712 [%]
# current:  +30.003 [A], rms_error:  0.0572 [%], max_error:  0.1276 [%]
# current:  +50.006 [A], rms_error:  0.0543 [%], max_error:  0.1337 [%]
# current:  +70.011 [A], rms_error:  0.0532 [%], max_error:  0.1375 [%]
# current:  +90.012 [A], rms_error:  0.0555 [%], max_error:  0.1375 [%]
# current: +110.014 [A], rms_error:  0.0661 [%], max_error:  0.1682 [%]
# current: +130.011 [A], rms_error:  0.0842 [%], max_error:  0.1890 [%]

# %%
# Plot Integrated Quadrupole Error for maximum current

data.rampup_excitation_curve_rms_error_plot(plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Hysteresis

# %%
# Absolute

data.hysteresis_absolute_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Relative

data.hysteresis_relative_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Save Excitation Data Files

# %%
# save average excitation data to file

data.save_excdata_average('M1')

# %%
# save excitation data of all magnets to separate files
data.save_excdata_individuals('M1')

# %% [markdown]
# ## Multipoles

# %%
# Horizontal kick

data.multipole_errors_kickx_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Vertical kick

# BD-021: big skew error!
data.multipole_errors_kicky_plot('M1', plt)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
